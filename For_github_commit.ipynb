# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Github_Folder/CodingDojang
# Out:
# /content/drive/MyDrive/Github_Folder/CodingDojang

# %%
# !git config --global user.email 'dailybook406@gmail.com'
# !git config --global user.name 'Chashoo414'

# %%
# !git status
